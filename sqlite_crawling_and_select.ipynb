IRANG 스마트베타4종결합"] ,["222170", "ARIRANG S&P한국배당성장"] ,["280940", "KODEX 골드선물인버스(H)"] ,["289670", "ARIRANG 국채선물10년"] ,["287320", "KBSTAR 200산업재"] ,["295860", "ARIRANG 200모멘텀"] ,["285020", "KBSTAR 200철강소재"] ,["098560", "TIGER 방송통신"] ,["301410", "ARIRANG 코스닥150선물인버스"] ,["256750", "KODEX 심천ChiNext(합성)"] ,["299080", "KINDEX 국채선물3년인버스"] ,["285010", "KBSTAR 200중공업"] ,["284980", "KBSTAR 200금융"] ,["287310", "KBSTAR 200경기소비재"] ,["301440", "ARIRANG 코스피중형주"] ,["299070", "KINDEX 국채선물10년인버스"] ,["228800", "TIGER 여행레저"] ,["105010", "TIGER 라틴35"] ,["222190", "ARIRANG 스마트베타 Momentum"] ,["091220", "TIGER 은행"] ,["139270", "TIGER 200 금융"] ,["138910", "KODEX 구리선물(H)"] ,["261270", "KODEX 미국달러선물인버스"] ,["200050", "KODEX 독일MSCI(합성)"] ,["139320", "TIGER 금은선물(H)"] ,["253160", "ARIRANG 200선물인버스2X"] ,["256450", "ARIRANG 심천차이넥스트(합성)"] ,["220130", "SMART 중국본토 중소형 CSI500(.."] ,["139310", "TIGER 금속선물(H)"] ,["140710", "KODEX 운송"] ,["301400", "ARIRANG 코스닥150"]]
codes = [[int(x), y] for x,y in codes]
inputdatas={}
for code in codes:
    inputdatas[code[0]] = code[1]


def get_stock_price_link_url(stock_id, count):
    return "http://m.stock.naver.com/api/item/getPriceDayList.nhn?code={:0=6d}&pageSize={}".format(int(stock_id), count)

def get_stock_price(stock_id, count=9000):
    link = get_stock_price_link_url(stock_id, count)
    retry = 3
    for _ in range(retry):
        req = requests.get(link)
        if req.status_code == 200:
            stock_rows = [ row for row in json.loads(req.text)['result']['list']]
            req.close()
            return  stock_rows
        print("{} retry!!".format(stock_id))
    return


with sqlite3.connect('etf_stock.db') as conn:
    cur = conn.cursor()
    cur.execute('''create table if not exists id_and_title(
                    id integer,
                    name text
               );''')
    cur.execute('''create table if not exists datas(
                    id integer,
                    date integer,
                    open integer,
                    high integer,
                    low integer,
                    close integer,
                    mount integer
               );''')


with sqlite3.connect('etf_stock.db') as conn:
    cur = conn.cursor()
    cur.execute('select * from id_and_title')
    rows = cur.fetchall()
    tempkeys = [row[0] for row in rows]
    outer = set(inputdatas.keys())-set(tempkeys)
    for stock_id in outer:
        cur.execute('insert into id_and_title(id,name) values (?,?)',(stock_id, inputdatas[stock_id]))
    conn.commit()


with sqlite3.connect('etf_stock.db') as conn:
    cur = conn.cursor()
    cur.execute('select * from id_and_title')
    rows = cur.fetchall()
    stock_ids = [row[0] for row in rows]
    for stock_id in stock_ids:
        cur.execute('select * from datas where id = ?', (stock_id,))
        datarows = cur.fetchall()
        datas = get_stock_price(stock_id)
        alldates = set([int(data['dt']) for data in datas])
        datarows_dates = set([data[1] for data in datarows])
        insertdate = alldates-datarows_dates
        if len(insertdate):
            print(stock_id)
        for data in datas:
            if int(data['dt']) in insertdate:
                cur.execute('insert into datas(id, date, open, high, low, close, mount) values(?,?,?,?,?,?,?)',(stock_id, int(data['dt']), int(data['ov']), int(data['hv']), int(data['lv']), int(data['ncv']), int(data['aq'])))
        conn.commit()

# %%
with sqlite3.connect('etf_stock.db') as conn:
    cur = conn.cursor()
    cur.execute('select * from id_and_title')
    rows = cur.fetchall()
    stock_ids = [row[0] for row in rows]
    #for stock_id in stock_ids:
    cur.execute('select id, cnt from (select id , count(*) as cnt from datas group by id order by cnt desc) where cnt >= 1000')
    datarows = cur.fetchall()
    print(len(datarows))
    for datarow in datarows:
        print(datarow[0], datarow[1])
# Out:
# 131
# 69500 3933
# 69660 3933
# 91160 3015
# 91170 3015
# 91180 3015
# 91210 3015
# 91220 3015
# 91230 3015
# 97750 2744
# 98560 2717
# 99140 2698
# 100910 2627
# 101280 2610
# 102110 2579
# 102780 2549
# 102960 2543
# 102970 2543
# 104520 2501
# 104530 2501
# 105010 2481
# 105190 2461
# 105780 2443
# 108590 2379
# 108450 2374
# 114100 2250
# 114260 2250
# 114460 2248
# 114470 2248
# 114820 2229
# 114800 2215
# 117460 2198
# 117690 2191
# 117680 2184
# 117700 2184
# 122090 2138
# 122260 2133
# 122630 2107
# 123310 2083
# 123320 2074
# 130730 1998
# 130680 1996
# 131890 1962
# 132030 1955
# 133690 1944
# 137610 1884
# 137930 1862
# 138230 1855
# 138520 1849
# 138530 1846
# 138540 1846
# 138910 1843
# 138920 1843
# 139660 1830
# 139220 1827
# 139230 1827
# 139240 1827
# 139250 1827
# 139260 1827
# 139270 1827
# 139280 1827
# 139290 1827
# 139310 1825
# 139320 1825
# 136340 1820
# 140570 1820
# 140580 1820
# 140700 1813
# 140710 1813
# 140950 1808
# 141240 1799
# 143460 1776
# ...

# %%
with sqlite3.connect('etf_stock.db') as conn:
    cur = conn.cursor()
    sql = 'select id, count(*) from (select datas.* from datas, (select date from datas where id = 200250) as dates where dates.date=datas.date) group by id'
    #for stock_id in stock_ids:
    cur.execute(sql)
    datarows = cur.fetchall()
    print(len(datarows), len(datarows)/1029)
    for datarow in datarows:
        print(datarow)
# Out:
# 391 0.37998056365403304
# (69500, 1029)
# (69660, 1029)
# (91160, 1029)
# (91170, 1029)
# (91180, 1029)
# (91210, 1029)
# (91220, 1029)
# (91230, 1029)
# (97750, 1029)
# (98560, 1029)
# (99140, 1029)
# (100910, 1029)
# (101280, 1029)
# (102110, 1029)
# (102780, 1029)
# (102960, 1029)
# (102970, 1029)
# (104520, 1029)
# (104530, 1029)
# (105010, 1029)
# (105190, 1029)
# (105780, 1029)
# (108450, 1029)
# (108590, 1029)
# (114100, 1029)
# (114260, 1029)
# (114460, 1029)
# (114470, 1029)
# (114800, 1029)
# (114820, 1029)
# (117460, 1029)
# (117680, 1029)
# (117690, 1029)
# (117700, 1029)
# (122090, 1029)
# (122260, 1029)
# (122630, 1029)
# (123310, 1029)
# (123320, 1029)
# (130680, 1029)
# (130730, 1029)
# (131890, 1029)
# (132030, 1029)
# (133690, 1029)
# (136340, 1029)
# (137610, 1029)
# (137930, 1029)
# (138230, 1029)
# (138520, 1029)
# (138530, 1029)
# (138540, 1029)
# (138910, 1029)
# (138920, 1029)
# (139220, 1029)
# (139230, 1029)
# (139240, 1029)
# (139250, 1029)
# ...
